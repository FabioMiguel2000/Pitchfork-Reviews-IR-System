# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_json("../assets/reviewsCompleteTablesContent.json", orient='records')

# %%
plt = data['score'].plot(kind='kde')
plt.set_xlim(0,10)
# Out:
# (0.0, 10.0)

# %%
print(data['score'].mean())
print(data['score'].median())
print(data['score'].max())
print(data['score'].min())
# Out:
# 7.006162784383945
# 7.2
# 10.0
# 0.0

# %%
scores = np.round(np.array(data['score']))

amount = []
for i in range(11):
    amount.append(np.count_nonzero(scores == i))

ide = np.array([i for i in range(11)])

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ide, amount)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(ide, amount)
ax.set_yscale('log')
plt.show()
